# %% [markdown]
# ### Importing Dataset

# %%
# importing require libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing dataset

df = pd.read_csv('Movie_regression.csv', header=0)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df.shape
# Out:
# (506, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ### Missing Value Imputation

# %%
# missing value imputation of variable "Time_taken"
# calculating mean of Time_taken

TT_mean = df['Time_taken'].mean()

# %%
df['Time_taken'].fillna(value = TT_mean, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# ### Dummy Variable Creation

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
# Value count of "3D_available"

df['3D_available'].value_counts()
# Out:
# YES    279
# NO     227
# Name: 3D_available, dtype: int64

# %%
# Value count of "Genre"

df['Genre'].value_counts()
# Out:
# Thriller    183
# Comedy      155
# Drama        97
# Action       71
# Name: Genre, dtype: int64

# %%
df = pd.get_dummies(df, columns = ['3D_available', 'Genre'], drop_first = True)

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %% [markdown]
# ### Dividing DF into Dependent and Independent Variable

# %%
# DF of Independent Variables
x = df.loc[:, df.columns!='Collection']
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views  Time_taken  Twitter_hastags  \
# ...

# %%
x.shape
# Out:
# (506, 19)

# %%
# Series of Dependent Variable
y = df['Collection']
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head()
# Out:
# 0    48000
# 1    43200
# 2    69400
# 3    66800
# 4    72400
# Name: Collection, dtype: int64

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
# checking shape of all data

print("x_train", x_train.shape)
print("x_test", x_test.shape)
print("y_train", y_train.shape)
print("y_test", y_test.shape)
# Out:
# x_train (404, 19)
# x_test (102, 19)
# y_train (404,)
# y_test (102,)

# %% [markdown]
# ### Training Regression Tree

# %%
from sklearn import tree

# %%
regtree = tree.DecisionTreeRegressor(max_depth = 3)

# %%
regtree.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# #### Predicting Values

# %%
y_train_pred = regtree.predict(x_train)

# %%
y_test_pred = regtree.predict(x_test)

# %% [markdown]
# #### Model Performance

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test, y_test_pred)
# Out:
# 111364081.74002264

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.8364651040556869

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.6540678457568934

# %% [markdown]
# #### Plotting Decision Tree

# %%
dotData = tree.export_graphviz(regtree, out_file=None)

# %%
from IPython.display import Image

# %%
import pydotplus

# %%
graph = pydotplus.graph_from_dot_data(dotData)

# %%
Image(graph.create_png())

# %% [markdown]
# ### Controlling Tree Growth
#
# <h4>Maximum numbers of levels in Tree</h4>

# %%
regtree1 = tree.DecisionTreeRegressor(max_depth=3)
regtree1.fit(x_train, y_train)
dotData1 = tree.export_graphviz(regtree1, out_file=None, feature_names=x_train.columns, filled = True)
graph1 = pydotplus.graph_from_dot_data(dotData1)
Image(graph1.create_png())

# %% [markdown]
# #### Minimum observations at Internal Node

# %%
regtree2 = tree.DecisionTreeRegressor(min_samples_split=40)
regtree2.fit(x_train, y_train)
dotData2 = tree.export_graphviz(regtree2, out_file=None, feature_names=x_train.columns, filled = True)
graph2 = pydotplus.graph_from_dot_data(dotData2)
Image(graph2.create_png())

# %% [markdown]
# ### Minimum Observations at Leaf Node

# %%
regtree3 = tree.DecisionTreeRegressor(min_samples_leaf=25, max_depth = 5)
regtree3.fit(x_train, y_train)
dotData3 = tree.export_graphviz(regtree3, out_file=None, feature_names=x_train.columns, filled = True)
graph3 = pydotplus.graph_from_dot_data(dotData3)
Image(graph3.create_png())
